# %%
import os
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.vba.vic.gov.au/about/data'

# %%
r = requests.get(a)

# %%
soup = BeautifulSoup(r.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Data | Victorian Building Authority</title>
# <!-- Misc Metadata -->
# <meta charset="utf-8"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <!-- Custom Metadata -->
# <!-- Global Schema //-->
# <!-- SEO //-->
# <meta content="Key data sets and statistics about our functions and services are available here." name="description"/>
# <!-- Content //-->
# <meta content="Data" name="DCTERMS.title">
# <meta content="" name="DCTERMS.subject">
# <meta content="Key data sets and statistics about our functions and services are available here." name="DCTERMS.description"/>
# <meta content="Key data sets and statistics about our functions and services are available here." name="DCTERMS.description.short">
# ...

# %%
xlsb_links = {}

for link in soup.find_all('a', href=lambda href: href and '.xlsb' in href):
    if 'Building Permits' in link.text:
        xlsb_links[link.text] = link['href']

# %%
# Create a subdirectory if it doesn't exist
subdirectory = 'vba_xlsb_docs'
os.makedirs(subdirectory, exist_ok=True)

# %%
# Download and save each XLSB document
for url in xlsb_links.values():
    response = requests.get(url)
    
    # Extract the filename from the URL
    filename = os.path.join(subdirectory, os.path.basename(url))
    
    with open(filename, 'wb') as file:
        file.write(response.content)
    
    print(f"Downloaded and saved: {filename}")
# Out:
# Downloaded and saved: vba_xlsb_docs/20240219-Raw-Data-January-2024.xlsb
# Downloaded and saved: vba_xlsb_docs/20240067-Raw-Data-December-2023.xlsb
# Downloaded and saved: vba_xlsb_docs/December-2022-Raw-data.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2021-Dec.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2020.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2019.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2018.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2017.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2016.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2015.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2014.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2013.xlsb
# Downloaded and saved: vba_xlsb_docs/VBA-DataVic-Building-Permits-2012.xlsb
# ...
